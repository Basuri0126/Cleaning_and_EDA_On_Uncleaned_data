# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_excel('/content/smartphones.xlsx')

# %%
df2.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
# 20. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df2.isna().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2['price']
# Out:
# 0       ₹54,999
# 1       ₹19,989
# 2       ₹16,499
# 3       ₹14,999
# 4       ₹24,999
#          ...
# 1015    ₹34,990
# 1016    ₹14,990
# 1017    ₹28,990
# 1018    ₹19,990
# 1019    ₹24,990
# Name: price, Length: 1020, dtype: object

# %%
df2['price'] = df2['price'].str[1:].str.replace(',', '').astype('int')
# df1['price'] = df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
df3 = df2.copy()

# %%
df3
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df3 = df3.reset_index()

# %%
df3['index'] = df3['index'] + 2

# %%
df3
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df3[df3['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df3[df3['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# ...

# %%
df3 = df3[df3['price'] >= 3500]

# %%
df3
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df3[df3['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
# ...

# %%
df3.drop([645, 857, 882, 925], inplace=True)
# Out:
# <ipython-input-20-84b1f000b332>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop([645, 857, 882, 925], inplace=True)

# %%
df3[df3['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
df3.drop([582], inplace=True)
# Out:
# <ipython-input-22-7c1f0646e8eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop([582], inplace=True)

# %%
df3[df3['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# ...

# %%
df3[df3['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df3.drop([376,754],inplace=True)
# Out:
# <ipython-input-25-d622c03ac8fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop([376,754],inplace=True)

# %%
temp_df = df3[df3['index'].isin(battery_rows)]

# %%
x = temp_df.iloc[:, 7:].shift(1, axis=1).values

# %%
df3.loc[temp_df.index, temp_df.columns[7:]] = x

# %%
df3[df3['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df3[df3['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
df3.drop([155, 271],inplace=True)
# Out:
# <ipython-input-31-8787569ce989>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop([155, 271],inplace=True)

# %%
temp_df1 = df3[df3['index'].isin(camera_rows)]

# %%
temp_df1 = temp_df1[~temp_df1['camera'].str.contains('MP')]

# %%
temp_df1.loc[temp_df1.index, 'camera'] = temp_df1['card'].values

# %%
temp_df1
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# ...

# %%
df3.card.value_counts()
# Out:
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# ...

# %%
temp_df2 = df3[df3['card'].str.contains('MP')]

# %%
df3.loc[temp_df2.index, 'card'] = 'Memory Card Not Supported'

# %%
df3.card.value_counts()
# Out:
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              149
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 128 GB       5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
temp_df3 = df3[~df3['card'].str.contains('Memory Card')]

# %%
df3.loc[temp_df3.index, 'os'] = temp_df3.card.values

# %%
df3.loc[temp_df3.index,'card'] = 'Memory Card Not Supported'

# %%
df3['card'].value_counts()
# Out:
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 128 GB       5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: card, dtype: int64

# %%
df3.os.value_counts()
# Out:
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     28
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Android v12.1                           2
# EMUI v12                                2
# ...

# %%
temp_df4 = df3[df3['os'] == 'Bluetooth']

# %%
df3.loc[temp_df4.index, 'os'] = np.nan

# %%
df3.os.value_counts()
# Out:
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     28
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# HarmonyOS v2.0                          2
# Memory Card (Hybrid), upto 2 TB         2
# Android v5.1.1 (Lollipop)               2
# Android v12.1                           2
# EMUI v12                                2
# ...

# %%
df3.display.value_counts()
# Out:
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          54
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch              36
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           25
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch             23
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            22
# 6.51 inches, 720 x 1600 px Display with Water Drop Notch             21
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole           19
# 6.43 inches, 1080 x 2400 px Display with Punch Hole                  16
# 6.62 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          15
# 6.53 inches, 720 x 1600 px Display with Water Drop Notch             14
# 6.4 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            14
# 6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          11
# 6.7 inches, 1440 x 3216 px, 120 Hz Display with Punch Hole           10
# ...

# %%
df3.shape
# Out:
# (981, 12)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 981 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      981 non-null    int64
#  1   model      981 non-null    object
#  2   price      981 non-null    int64
#  3   rating     878 non-null    float64
#  4   sim        981 non-null    object
#  5   processor  981 non-null    object
#  6   ram        981 non-null    object
#  7   battery    970 non-null    object
#  8   display    981 non-null    object
#  9   camera     981 non-null    object
#  10  card       981 non-null    object
#  11  os         980 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 131.9+ KB

# %%
brand_name = df3['model'].str.split(' ').str.get(0)

# %%
df3.insert(1, 'brand_name', brand_name)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    OnePlus              OnePlus 11 5G  54999    89.0
# 1      3    OnePlus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    Samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   Motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     Realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %%
df3['brand_name'] = df3['brand_name'].str.lower()
# Out:
# <ipython-input-55-e29d02b91908>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['brand_name'] = df3['brand_name'].str.lower()

# %%
df3['sim'].head(10)
# Out:
# 0           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 5           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 6           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 7    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 8           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Name: sim, dtype: object

# %%
has_5g = df3['sim'].str.contains('5G')
has_nfc = df3['sim'].str.contains('NFC')

has_ir_blaster = df3['sim'].str.contains('IR Blaster')

# %%
df3.insert(6, 'has_5g', has_5g)
df3.insert(7, 'has_nfc', has_nfc)
df3.insert(8, 'has_ir_blaster', has_ir_blaster)

# %%
processor_name = df3['processor'].str.split(',').str.get(0)

# %%
num_cores = df3['processor'].str.split(',').str.get(1)

# %%
processor_speed = df3['processor'].str.split(',').str.get(2)

# %%
df3.insert(10,'processor_name',processor_name)
df3.insert(11,'num_cores',num_cores)
df3.insert(12,'processor_speed',processor_speed)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
df3['processor_name'] = df3['processor_name'].str.strip()
# Out:
# <ipython-input-64-a477a056326b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['processor_name'] = df3['processor_name'].str.strip()

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
temp_df = df3[df3['processor_name'].str.contains('Core')][['processor_name', 'num_cores',	'processor_speed']].shift(1, axis=1)

# %%
temp_df.shape
# Out:
# (20, 3)

# %%
df3.loc[temp_df.index, ['processor_name', 'num_cores',	'processor_speed']] = temp_df.values

# %%
df3['processor_name'].value_counts()
# Out:
# Helio P35                  30
# Snapdragon 695             29
# Dimensity 700 5G           29
# Snapdragon 8+ Gen1         26
# Snapdragon  695            24
# Snapdragon 680             24
# Snapdragon 8 Gen2          23
# Helio G35                  20
# Snapdragon  680            19
# Snapdragon 8 Gen1          18
# Snapdragon  8 Gen1         18
# Bionic A15                 16
# Snapdragon 870             16
# Helio G96                  15
# Dimensity  810 5G          15
# Helio G80                  14
# Helio G99                  14
# Snapdragon  8+ Gen1        13
# Snapdragon 778G            12
# Snapdragon  888            12
# Dimensity 1080             12
# Dimensity 810 5G           12
# Snapdragon 888             11
# Dimensity  920 5G          11
# Helio G37                  11
# Helio G95                  10
# Helio  G85                 10
# Helio A22                  10
# Helio G25                  10
# Bionic  A16                10
# Snapdragon 720G             9
# ...

# %%
df3.loc[856]
# Out:
# index                                                858
# brand_name                                       samsung
# model                            Samsung Galaxy A01 Core
# price                                               4999
# rating                                               NaN
# sim                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# has_5g                                             False
# has_nfc                                            False
# has_ir_blaster                                     False
# processor          (28 nm), Quad Core, 1.5 GHz Processor
# processor_name                                   (28 nm)
# num_cores                                      Quad Core
# processor_speed                        1.5 GHz Processor
# ram                              1 GB RAM, 16 GB inbuilt
# battery                                 3000 mAh Battery
# display                5.3 inches, 720 x 1480 px Display
# ...

# %%
df3.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
processor_brand = df3['processor_name'].str.split().str.get(0).str.lower()

# %%
df3.insert(9, 'processor_brand', processor_brand)

# %%
df3['num_cores'].value_counts()
# Out:
#  Octa Core              865
#  Hexa Core               31
#  Quad Core               31
#  Octa Core Processor     19
# Octa Core Processor       9
#  Hexa Core Processor      8
# Quad Core                 6
# Octa Core                 5
# Name: num_cores, dtype: int64

# %%
df3['num_cores'] = df3['num_cores'].str.strip().str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')
# Out:
# <ipython-input-75-5abc7121c0fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['num_cores'] = df3['num_cores'].str.strip().str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
df3['num_cores'].value_counts()
# Out:
# Octa Core    898
# Hexa Core     39
# Quad Core     37
# Name: num_cores, dtype: int64

# %%
df3['processor_speed'].str.split(' ').str.get(1).str.split(' ').get(0)
# Out:
# ['3.2\u2009GHz']

# %%
# there is \u2009 thin space

# %%
df3['processor_speed'].str.split(' ').str.get(1).str.split('\u2009').str.get(0).value_counts()
# Out:
# 2       145
# 2.2     135
# 2.4     128
# 3.2      94
# 2.3      86
# 3        53
# 2.84     36
# 2.05     28
# 2.5      23
# 1.8      23
# 1.6      20
# 2.85     19
# 3.22     18
# 3.1      15
# 2.6      14
# 2.9      13
# 1.82     10
# 1.3      10
# 2.73      9
# 2.8       9
# 3.05      8
# 2.36      8
# 2.7       5
# 1.4       5
# 2.65      5
# 1.5       4
# 2.96      3
# 2.86      3
# 3.13      2
# 1.1       1
# 2.35      1
# 2.37      1
# 1.99      1
# 1.95      1
# 2.1       1
# 1.2       1
# Name: processor_speed, dtype: int64

# %%
df3['processor_speed'] = df3['processor_speed'].str.split(' ').str.get(1).str.split('\u2009').str.get(0)
# Out:
# <ipython-input-80-f864887afedc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['processor_speed'] = df3['processor_speed'].str.split(' ').str.get(1).str.split('\u2009').str.get(0)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand                                        processor  \
# ...

# %%
ram_capacity = df3['ram'].str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df3.insert(11, 'ram_capacity', ram_capacity)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand  ... ram_capacity     processor_name  num_cores  \
# ...

# %%
inbuilt_memory = df3['ram'].str.split(',').str.get(1).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df3.insert(12, 'internal_memory', inbuilt_memory)

# %%
df3[df3.ram_capacity == '1']
# Out:
#      index brand_name                    model  price  rating  \
# 399    401       itel                 itel P36   6490     NaN
# 477    479       vivo                 Vivo Y25   7499     NaN
# 735    737      tecno           Tecno Pop 5 Go   6999     NaN
# 744    746       itel                 itel S16   5990     NaN
# 794    796       itel                 itel A56   5490     NaN
# 856    858    samsung  Samsung Galaxy A01 Core   4999     NaN
# 907    909       itel             Itel A23 Pro   3999     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 399  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 477         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 735             Dual Sim, 3G, Wi-Fi   False    False           False
# 744  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 794  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# ...

# %%
df3['ram_capacity'] = df3['ram_capacity'].astype('float')
# Out:
# <ipython-input-88-c50e58e8b1c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ram_capacity'] = df3['ram_capacity'].astype('float')

# %%
df3['ram_capacity'].value_counts()
# Out:
# 8.0      339
# 6.0      234
# 4.0      215
# 12.0      85
# 3.0       53
# 2.0       32
# 16.0       9
# 1.0        7
# 64.0       3
# 18.0       2
# 512.0      2
# Name: ram_capacity, dtype: int64

# %%
df3[df3['ram_capacity'] > 18]
# Out:
#      index brand_name                             model   price  rating  \
# 439    441      apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488      nokia                     Nokia 8000 4G    6899     NaN
# 627    629      nokia                      Nokia 225 4G    3589     NaN
# 762    764      apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster processor_brand  ... internal_memory      processor_name  \
# ...

# %%
df3.drop([486, 627], inplace=True)
# Out:
# <ipython-input-91-a313fd19f071>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop([486, 627], inplace=True)

# %%
df3[df3['ram_capacity'] > 18]
# Out:
#      index brand_name                             model   price  rating  \
# 439    441      apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 762    764      apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster processor_brand  ... internal_memory      processor_name  \
# 439           False          bionic  ...             NaN         Bionic  A15
# 483            True      snapdragon  ...             NaN  Snapdragon 8+ Gen1
# 762           False          bionic  ...             NaN         Bionic  A15
#
#      num_cores processor_speed             ram  \
# ...

# %%
df3.loc[483, 'ram_capacity'] = 12
df3.loc[483, 'internal_memory'] = '512'

# %%
df3[df3['ram_capacity'] > 18]
# Out:
#      index brand_name                   model  price  rating  \
# 439    441      apple  Apple iPhone SE 3 2022  43900     NaN
# 762    764      apple       Apple iPhone SE 4  49990    60.0
#
#                                          sim  has_5g  has_nfc  has_ir_blaster  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
#
#     processor_brand  ... internal_memory  processor_name  num_cores  \
# 439          bionic  ...             NaN     Bionic  A15  Hexa Core
# 762          bionic  ...             NaN     Bionic  A15  Hexa Core
#
#     processor_speed            ram battery                            display  \
# 439            3.22  64 GB inbuilt    None  4.7 inches, 750 x 1334 px Display
# 762            3.22  64 GB inbuilt    None  6.1 inches, 750 x 1580 px Display
#
#                                 camera                       card       os
# ...

# %%
df3['ram_capacity'].value_counts()
# Out:
# 8.0     339
# 6.0     234
# 4.0     215
# 12.0     86
# 3.0      53
# 2.0      32
# 16.0      9
# 1.0       7
# 18.0      2
# 64.0      2
# Name: ram_capacity, dtype: int64

# %%
df3.loc[[439, 762], ['internal_memory']] = ['64', '64']

# %%
df3[df3['ram_capacity'] > 18]
# Out:
#      index brand_name                   model  price  rating  \
# 439    441      apple  Apple iPhone SE 3 2022  43900     NaN
# 762    764      apple       Apple iPhone SE 4  49990    60.0
#
#                                          sim  has_5g  has_nfc  has_ir_blaster  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
#
#     processor_brand  ... internal_memory  processor_name  num_cores  \
# 439          bionic  ...              64     Bionic  A15  Hexa Core
# 762          bionic  ...              64     Bionic  A15  Hexa Core
#
#     processor_speed            ram battery                            display  \
# 439            3.22  64 GB inbuilt    None  4.7 inches, 750 x 1334 px Display
# 762            3.22  64 GB inbuilt    None  6.1 inches, 750 x 1580 px Display
#
#                                 camera                       card       os
# ...

# %%
df3.loc[[439, 762], ['ram_capacity']] = [4.0, 4.0]

# %%
df3[df3['ram_capacity'] > 18]
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor_brand, processor, ram_capacity, internal_memory, processor_name, num_cores, processor_speed, ram, battery, display, camera, card, os]
# Index: []
#
# [0 rows x 22 columns]

# %%
df3.ram_capacity.value_counts()
# Out:
# 8.0     339
# 6.0     234
# 4.0     217
# 12.0     86
# 3.0      53
# 2.0      32
# 16.0      9
# 1.0       7
# 18.0      2
# Name: ram_capacity, dtype: int64

# %% [markdown]
# ###### internal memory

# %%
df3.internal_memory.value_counts()
# Out:
# 128    523
# 64     193
# 256    157
# 32      66
# 512     22
# 16      12
# 1        5
# 8        1
# Name: internal_memory, dtype: int64

# %%
df3['internal_memory'] = df3.internal_memory.astype('float')
# Out:
# <ipython-input-102-6635e3e5f106>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['internal_memory'] = df3.internal_memory.astype('float')

# %%
temp_df = df3[df3['internal_memory'] == 1]

# %%
df3.loc[temp_df.index, 'internal_memory'] = 1024

# %%
df3.internal_memory.value_counts()
# Out:
# 128.0     523
# 64.0      193
# 256.0     157
# 32.0       66
# 512.0      22
# 16.0       12
# 1024.0      5
# 8.0         1
# Name: internal_memory, dtype: int64

# %%
df3['internal_memory'].value_counts()
# Out:
# 128.0     523
# 64.0      193
# 256.0     157
# 32.0       66
# 512.0      22
# 16.0       12
# 1024.0      5
# 8.0         1
# Name: internal_memory, dtype: int64

# %%
battery_capacity = df3['battery'].str.split(' ').str.get(0).str.split('\u2009').str[0].astype('float')

# %%
df3.insert(16, 'battery_capacity', battery_capacity)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand  ...     processor_name  num_cores  processor_speed  \
# ...

# %%
fast_charging = df3['battery'].str.split('with').str.get(1).str.split(' ').str.get(1).str.findall(r'\d{2,3}').str.get(0)

# %%
df3.insert(17,'fast_charging',fast_charging)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand  ...  num_cores  processor_speed  battery_capacity  \
# ...

# %%
df3[df3['battery_capacity'] == 22000]
# Out:
#      index brand_name         model  price  rating  \
# 874    876     doogee  Doogee V Max  45999    88.0
#
#                                     sim  has_5g  has_nfc  has_ir_blaster  \
# 874  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#     processor_brand  ...  num_cores  processor_speed  battery_capacity  \
# 874       dimensity  ...  Octa Core              2.6           22000.0
#
#     fast_charging                        ram  \
# 874            33  12 GB RAM, 256 GB inbuilt
#
#                                       battery  \
# 874  22000 mAh Battery with 33W Fast Charging
#
#                                                display  \
# 874  6.58 inches, 1080 x 2408 px, 120 Hz Display wi...
#
#                                                 camera  \
# 874  108 MP + 20 MP + 16 MP Triple Rear & 32 MP Fro...
#
#                                 card           os
# 874  Memory Card (Hybrid), upto 2 TB  Android v12
#
# [1 rows x 24 columns]

# %%
df3.fast_charging.value_counts()
# Out:
# 33     152
# 18     128
# 67      65
# 25      53
# 120     46
# 15      43
# 80      42
# 66      37
# 10      33
# 30      32
# 65      30
# 44      23
# 45      17
# 20      10
# 68       8
# 100      7
# 150      7
# 125      6
# 22       5
# 40       5
# 60       4
# 55       3
# 21       2
# 210      2
# 50       2
# 180      1
# 200      1
# 240      1
# 19       1
# 135      1
# 165      1
# 27       1
# Name: fast_charging, dtype: int64

# %%
screen_size = df3['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype('float')

# %%
df3.insert(22, 'screen_size', screen_size)

# %%
resolution = df3['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df3.insert(23, 'resolution', resolution)

# %%
refresh_rate = df3['display'].str.strip().str.split(',').str.get(2).str.strip().str.split(' ').str.get(0).apply(lambda x : 60 if pd.isna(x) else x).astype(int)

# %%
df3.insert(24, 'refresh_rate', refresh_rate)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand  ... fast_charging                        ram  \
# 0      snapdragon  ...           100  12 GB RAM, 256 GB inbuilt
# ...

# %%
def camera_extract(text):
  if 'Quad' in text:
    return 4
  elif 'Triple' in text:
    return 3
  elif 'Dual' in text:
    return 2
  elif 'Missing' in text:
    return 'Missing'
  else:
    return 1

# %%
rear_camera_count = df3['camera'].str.strip().str.split('&').str.get(0).apply(camera_extract)

# %%
df3.insert(22, 'rear_camera_counts', rear_camera_count)

# %%
front_camera_count = df3['camera'].str.strip().str.split('&').str.get(1).fillna('Missing').apply(camera_extract)

# %%
df3.insert(23, 'front_camera_count', front_camera_count)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand  ...                                   battery  \
# 0      snapdragon  ...  5000 mAh Battery with 100W Fast Charging
# ...

# %%
df3[df3['front_camera_count'] == 'Missing']
# Out:
#       index brand_name                                     model   price  \
# 69       71       oppo                          Oppo Find N Fold   99990
# 98      100       vivo                            Vivo X Fold 5G  106990
# 159     161       oppo                           Oppo Find N2 5G   94990
# 236     238     xiaomi                      Xiaomi Mix Fold 2 5G  106990
# 306     308    samsung                   Samsung Galaxy Z Flip 3   69999
# 321     323    samsung                   Samsung Galaxy Z Fold 4  154998
# 322     324     royole                          Royole FlexPai 2  109999
# 365     367       oppo                          OPPO Find N Flip   89990
# 392     394       oppo                         OPPO Find N2 Flip   70990
# 462     464     xiaomi                       Xiaomi Mi Mix Alpha  199990
# 482     484       vivo                          Vivo X Fold Plus  113990
# 504     506    samsung                Samsung Galaxy Z Flip 4 5G   89999
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand                                        processor  \
# ...

# %%
df3[df3['camera'] == 'Foldable']
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor_brand, processor, ram_capacity, internal_memory, processor_name, num_cores, processor_speed, battery_capacity, fast_charging, ram, battery, display, camera, rear_camera_counts, front_camera_count, screen_size, resolution, refresh_rate, card, os]
# Index: []

# %%
temp_df = df3[df3['camera'] == 'Foldable Display, Dual Display']

# %%
df3.loc[temp_df.index, 'camera'] = '50 Mp'

# %%
df3['primary_camera_rear'] = df3['camera'].str.split(' ').str.get(0).str.strip().str.split('\u2009').str.get(0)
# Out:
# <ipython-input-147-18d872a3719e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['primary_camera_rear'] = df3['camera'].str.split(' ').str.get(0).str.strip().str.split('\u2009').str.get(0)

# %%
temp_df = df3[df3['primary_camera_rear'] == 'Foldable']

# %%
df3.loc[temp_df.index, 'primary_camera_rear'] = '50'

# %%
df3['primary_camera_front'] = df3['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)
# Out:
# <ipython-input-156-82978e466491>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['primary_camera_front'] = df3['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand                                        processor  \
# ...

# %%
df3[df3['card'] == 'Memory Card (Hybrid)']
# Out:
#      index brand_name                                      model  price  \
# 25      27    samsung                   Samsung Galaxy S20 FE 5G  31239
# 80      82   motorola                       Motorola Moto G72 4G  15999
# 147    149    samsung                      Samsung Galaxy M34 5G  16999
# 151    153   motorola                          Motorola Moto G52  11999
# 178    180       vivo                                Vivo Y75 5G  21990
# 204    206   motorola        Motorola Moto G52 (6GB RAM + 128GB)  12999
# 248    250   motorola                          Motorola Moto G73  25999
# 254    256     xiaomi                Xiaomi Redmi Note 11 Pro 5G  17990
# 281    283       vivo                               Vivo V23e 5G  21994
# 305    307     xiaomi                    Xiaomi Mi 11 Lite NE 5G  21890
# 441    443       poco                                Poco X3 Pro  19650
# 470    472     xiaomi  Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)  22999
# ...

# %%
df3.card.value_counts()
# Out:
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   88
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 128 GB       5
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card Supported, upto 32 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: card, dtype: int64

# %%
df3[df3['card'] == 'Not Specified']
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor_brand, processor, ram_capacity, internal_memory, processor_name, num_cores, processor_speed, battery_capacity, fast_charging, ram, battery, display, camera, rear_camera_counts, front_camera_count, screen_size, resolution, refresh_rate, card, os, primary_camera_rear, primary_camera_front]
# Index: []

# %%
df3['extended_memory_limit'] = df3.card.apply(lambda x: '0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported', 'Not Specified')
# Out:
# <ipython-input-168-c11d973b0e6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['extended_memory_limit'] = df3.card.apply(lambda x: '0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported', 'Not Specified')

# %%
df3.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#   processor_brand                                        processor  \
# ...

# %%
df3.extended_memory_limit.value_counts()
# Out:
# 0                       362
# 1 TB                    262
# 512 GB                  116
# 256 GB                  100
# Not Specified            88
# Memory Card (Hybrid)     30
# 128 GB                    8
# 2 TB                      6
# 32 GB                     3
# 64 GB                     3
# 1000 GB                   1
# Name: extended_memory_limit, dtype: int64

# %%
df3.os.value_counts()
# Out:
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     28
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# iOS v13                                 4
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v15.0                               3
# Memory Card (Hybrid), upto 256 GB       2
# HarmonyOS v2.0                          2
# Memory Card (Hybrid), upto 2 TB         2
# Android v5.1.1 (Lollipop)               2
# Android v6.0 (Marshmallow)              2
# Android v12.1                           2
# EMUI v12                                2
# ...

# %%
temp_df = df3[df3['os'].str.contains('Memory Card')]

# %%
df3.loc[temp_df.index, 'os'] = 'Not Specified'

# %%
df3.os.value_counts()
# Out:
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  28
# Android v10.0                       23
# iOS v16                             15
# Not Specified                       14
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# iOS v13                              4
# Android v8.0 (Oreo)                  4
# Android v11.0                        4
# iOS v15.0                            3
# EMUI v12                             2
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# Android                              1
# ...

# %%
def os_extractor(text):
  if 'Android' in text:
    return 'android'
  elif 'ios' in text:
    return 'IOS'
  elif 'Not Specified':
    return text
  elif 'HarmonyOS' in text:
    return 'harmonyOS'
  elif 'Hongmeng' in text:
    return 'hongmeng'
  elif 'Pragati' in text:
    return 'pargati OS'
  elif 'Harmony' in text:
    return 'harmony'
  elif 'EMUI' in text:
    return 'emui'

# %%
df3['os'] = df3['os'].apply(os_extractor)
# Out:
# <ipython-input-181-16617386b404>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['os'] = df3['os'].apply(os_extractor)

# %%
export_df = df3.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])

# %%
export_df.to_csv('smartphone_cleaned_v2.csv',index=False)
